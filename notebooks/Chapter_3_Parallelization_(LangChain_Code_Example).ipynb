# %% [markdown]
# <a href="https://colab.research.google.com/github/cmhrabi/AgenticDesignPatterns/blob/main/notebooks/Chapter_3_Parallelization_(LangChain_Code_Example).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain langchain-community langchain-openai langgraph
# Out:
# Requirement already satisfied: langchain in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (0.3.27)
# Requirement already satisfied: langchain-community in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (0.3.31)
# Requirement already satisfied: langchain-openai in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (0.3.35)
# Requirement already satisfied: langgraph in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (0.6.10)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (2.12.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: certifi in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.3 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-community) (3.13.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-community) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-openai) (2.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langgraph) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langgraph) (0.6.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/calumhrabi/AgenticDesignPatterns/.venv/lib/python3.14/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import asyncio
from typing import Optional

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# --- Configuration ---
# Ensure your API key environment variable is set (e.g., OPENAI_API_KEY)
try:
    llm: Optional[ChatOpenAI] = ChatOpenAI(
        api_key=os.getenv("OPENROUTER_API_KEY"),
        base_url=os.getenv("OPENROUTER_BASE_URL"),
        model="anthropic/claude-sonnet-4",
        temperature=0
    )
    if llm:
        print(f"Language model initialized: {llm.model_name}")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None


# --- Define Independent Chains ---
# These three chains represent distinct tasks that can be executed in parallel.

summarize_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the following topic concisely:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

questions_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Generate three interesting questions about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

terms_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Identify 5-10 key terms from the following topic, separated by commas:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

random_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Provide a random fun fact about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)


# --- Build the Parallel + Synthesis Chain ---

# 1. Define the block of tasks to run in parallel. The results of these,
#    along with the original topic, will be fed into the next step.
map_chain = RunnableParallel(
    {
        "summary": summarize_chain,
        "questions": questions_chain,
        "key_terms": terms_chain,
        "random_fact": random_chain,
        "topic": RunnablePassthrough(),  # Pass the original topic through
    }
)

# 2. Define the final synthesis prompt which will combine the parallel results.
synthesis_prompt = ChatPromptTemplate.from_messages([
    ("system", """Based on the following information:
     Summary: {summary}
     Related Questions: {questions}
     Key Terms: {key_terms}
     Random Fact: {random_fact}
     Synthesize a comprehensive answer."""),
    ("user", "Original topic: {topic}")
])

# 3. Construct the full chain by piping the parallel results directly
#    into the synthesis prompt, followed by the LLM and output parser.
full_parallel_chain = map_chain | synthesis_prompt | llm | StrOutputParser()


# --- Run the Chain ---
async def run_parallel_example(topic: str) -> None:
    """
    Asynchronously invokes the parallel processing chain with a specific topic
    and prints the synthesized result.

    Args:
        topic: The input topic to be processed by the LangChain chains.
    """
    if not llm:
        print("LLM not initialized. Cannot run example.")
        return

    print(f"\n--- Running Parallel LangChain Example for Topic: '{topic}' ---")
    try:
        # The input to `ainvoke` is the single 'topic' string, which is
        # then passed to each runnable in the `map_chain`.
        response = await full_parallel_chain.ainvoke(topic)
        print("\n--- Final Response ---")
        print(response)
    except Exception as e:
        print(f"\nAn error occurred during chain execution: {e}")

if __name__ == "__main__":
    test_topic = "The history of space exploration"
    # In Python 3.7+, asyncio.run is the standard way to run an async function.
    await run_parallel_example(test_topic)
# Out:
# Language model initialized: anthropic/claude-sonnet-4
#
# --- Running Parallel LangChain Example for Topic: 'The history of space exploration' ---
#
# --- Final Response ---
# # The History of Space Exploration: From Cold War Competition to Commercial Innovation
#
# Space exploration represents one of humanity's greatest technological and scientific achievements, transforming from a Cold War battleground into a collaborative frontier that continues to push the boundaries of human knowledge and capability.
#
# ## Origins and Early Milestones
#
# Space exploration emerged in the mid-20th century as a direct consequence of Cold War tensions between the United States and Soviet Union. This geopolitical rivalry inadvertently accelerated human progress beyond Earth's atmosphere at an unprecedented pace.
#
# The space age officially began on October 4, 1957, when the Soviet Union launched **Sputnik 1**, the first artificial satellite. This basketball-sized object orbiting Earth shocked the world and demonstrated Soviet technological superiority, triggering the "space race." The competition intensified when Soviet cosmonaut **Yuri Gagarin** became the first human in space on April 12, 1961, completing one orbit around Earth.
#
# The United States responded with President Kennedy's bold 1961 declaration to land Americans on the Moon before the decade's end. This goal was spectacularly achieved on July 20, 1969, when **Apollo 11** astronauts Neil Armstrong and Buzz Aldrin became the first humans to walk on the lunar surface, with Armstrong's famous words: "That's one small step for man, one giant leap for mankind."
#
# ## Expansion and Technological Development
#
# The 1970s-1990s marked a period of sustained expansion and technological sophistication. Both superpowers developed **space stations** - the Soviets with their Salyut series and later Mir, while the Americans launched Skylab. These platforms enabled long-duration human spaceflight and scientific research in microgravity.
#
# The **Space Shuttle program** (1981-2011) revolutionized space access with its reusable spacecraft design, enabling complex missions including satellite deployment, space station construction, and the Hubble Space Telescope servicing missions.
#
# Simultaneously, **robotic exploration** expanded human reach across the solar system. The Viking missions provided the first successful Mars landings in 1976, while the Voyager probes, launched in 1977, conducted the "Grand Tour" of the outer planets, sending back stunning images and data from Jupiter, Saturn, Uranus, and Neptune.
#
# ## Modern Era and Technological Innovation
#
# The 21st century has witnessed remarkable diversification in space exploration. The **International Space Station** (ISS), operational since 2000, represents unprecedented international cooperation, hosting astronauts from multiple nations conducting cutting-edge research.
#
# Perhaps most significantly, **private companies** have emerged as major players. SpaceX has revolutionized launch costs with reusable rockets, while companies like Blue Origin and Virgin Galactic are developing commercial spaceflight capabilities. This privatization has dramatically reduced costs and increased launch frequency.
#
# Recent achievements include increasingly sophisticated **Mars exploration** through rovers like Curiosity and Perseverance, which have provided detailed analysis of Martian geology and searched for signs of past life. The **James Webb Space Telescope**, launched in 2021, has already transformed our understanding of the early universe with unprecedented infrared observations.
#
# ## Transformative Impact on Society
#
# Space exploration's influence extends far beyond scientific discovery. The technological innovations required for space missions have produced numerous **spin-off technologies** that revolutionized daily life: satellite communications, GPS navigation, weather forecasting, medical imaging devices, memory foam, cordless tools, and water purification systems.
#
# The program has also fostered **international cooperation**, with the ISS serving as a model for peaceful collaboration even during periods of terrestrial political tension. Space exploration has inspired generations to pursue STEM careers and has fundamentally changed humanity's perspective on Earth as a fragile, interconnected system.
#
# ## Current Trajectory and Future Prospects
#
# Today's space exploration focuses on several ambitious goals: returning humans to the Moon through NASA's Artemis program, establishing sustainable lunar bases, and preparing for eventual human missions to Mars. Private companies are developing space tourism, asteroid mining capabilities, and satellite mega-constellations for global internet coverage.
#
# The field has evolved from a two-nation competition into a diverse ecosystem involving government agencies, private companies, and international partnerships. This transformation has made space more accessible while maintaining the spirit of exploration and discovery that has driven human progress beyond Earth for over six decades.
#
# Space exploration continues to represent humanity's boldest endeavor - pushing technological limits, expanding scientific knowledge, and inspiring us to reach beyond our planetary boundaries toward a future among the stars.
